# %%
import numpy as np
import pandas as pd
import os
from glob import glob

from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from scipy.optimize import root_scalar

from joblib import dump, load

from expon_mixture import ExponMixture

# %%
fits = pd.read_csv('./fits/expon_mix_2comp_fits.txt', index_col=0)

# %%
fits[fits['p1']<1.0].describe()
# Out:
#                p1          p2       lambda1       lambda2
# count  158.000000  158.000000  1.580000e+02  1.580000e+02
# mean     0.145675    0.854325  3.613421e+07  2.132482e+09
# std      0.299654    0.299654  4.188702e+08  1.239764e+10
# min      0.003333    0.003333  1.800000e+01  4.599383e+02
# 25%      0.013333    0.933333  1.117500e+02  3.081959e+05
# 50%      0.023333    0.976667  2.767045e+02  3.456719e+06
# 75%      0.066667    0.986667  7.069048e+02  5.270312e+07
# max      0.996667    0.996667  5.248641e+09  1.305466e+11

# %%
fits
# Out:
#                                                           p1        p2  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed2473397791...  1.000000       NaN
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf  1.000000       NaN
# barthel/n210/gen_n210_m903_k3SAT_seed4006075830...  1.000000       NaN
# barthel/n210/gen_n210_m903_k3SAT_seed1547818438...  1.000000       NaN
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...  1.000000       NaN
# ...                                                      ...       ...
# qhid/n70/gen_n70_m385_k3SAT_seed2030441879.cnf      1.000000       NaN
# qhid/n70/gen_n70_m385_k3SAT_seed3717411169.cnf      1.000000       NaN
# qhid/n70/gen_n70_m385_k3SAT_seed684617509.cnf       1.000000       NaN
# qhid/n70/gen_n70_m385_k3SAT_seed1293934752.cnf      1.000000       NaN
# qhid/n70/gen_n70_m385_k3SAT_seed2538753387.cnf      0.006667  0.993333
#
#                                                          lambda1       lambda2
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed2473397791...  3.214107e+03           NaN
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf  1.342518e+04           NaN
# barthel/n210/gen_n210_m903_k3SAT_seed4006075830...  1.295157e+03           NaN
# barthel/n210/gen_n210_m903_k3SAT_seed1547818438...  1.365623e+03           NaN
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...  1.511253e+03           NaN
# ...                                                          ...           ...
# qhid/n70/gen_n70_m385_k3SAT_seed2030441879.cnf      3.993567e+02           NaN
# qhid/n70/gen_n70_m385_k3SAT_seed3717411169.cnf      2.097433e+02           NaN
# qhid/n70/gen_n70_m385_k3SAT_seed684617509.cnf       2.370867e+02           NaN
# qhid/n70/gen_n70_m385_k3SAT_seed1293934752.cnf      1.008646e+11           NaN
# qhid/n70/gen_n70_m385_k3SAT_seed2538753387.cnf      1.020000e+02  1.962812e+07
#
# [300 rows x 4 columns]

# %%
df = pd.read_csv('./calculate_features/features_train.csv')
df.set_index('instance', inplace=True)

# %%
df.head()
# Out:
#                                                     nvarsOrig  nclausesOrig  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...      210.0         903.0
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf      210.0         903.0
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...      210.0         903.0
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...      210.0         903.0
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...      210.0         903.0
#
#                                                     nvars  nclauses  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...  199.0     892.0
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf  203.0     897.0
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...  204.0     892.0
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...  201.0     894.0
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...  205.0     897.0
#
#                                                     reducedVars  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...     0.055276
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf     0.034483
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...     0.029412
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...     0.044776
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...     0.024390
#
#                                                     reducedClauses  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...        0.012332
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf        0.006689
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...        0.012332
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...        0.010067
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...        0.006689
#
#                                                     Pre-featuretime  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...              0.0
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf              0.0
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...              0.0
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...              0.0
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...              0.0
#
#                                                     vars-clauses-ratio  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...            0.223094
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf            0.226310
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...            0.228700
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...            0.224832
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...            0.228540
#
#                                                     POSNEG-RATIO-CLAUSE-mean  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                  0.488565
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                  0.493683
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                  0.501121
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                  0.495153
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                  0.487737
#
#                                                     POSNEG-RATIO-CLAUSE-coeff-variation  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                             0.604264
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                             0.586009
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                             0.583115
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                             0.609906
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                             0.589016
#
#                                                     ...  \
# instance                                            ...
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...  ...
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf  ...
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...  ...
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...  ...
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...  ...
#
#                                                     gsat_FirstLocalMinStep_Q.10  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                         39.0
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                         40.0
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                         40.0
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                         40.0
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                         40.0
#
#                                                     gsat_FirstLocalMinStep_Q.90  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                         52.0
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                         53.0
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                         53.0
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                         53.0
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                         53.0
#
#                                                     gsat_BestAvgImprovement_Mean  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                      0.566566
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                      0.550169
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                      0.554184
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                      0.579225
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                      0.563700
#
#                                                     gsat_BestAvgImprovement_CoeffVariance  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                               0.415860
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                               0.417447
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                               0.416429
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                               0.412855
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                               0.410805
#
#                                                     gsat_FirstLocalMinRatio_Mean  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                      0.857284
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                      0.849422
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                      0.858623
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                      0.860000
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                      0.863640
#
#                                                     gsat_FirstLocalMinRatio_CoeffVariance  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                               0.050368
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                               0.054019
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                               0.049907
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                               0.051025
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                               0.048454
#
#                                                     ls-gsat-featuretime  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                 2.72
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                 2.72
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                 2.62
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                 2.66
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                 2.70
#
#                                                     lobjois-mean-depth-over-vars  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                      0.388437
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                      0.365887
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                      0.365476
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                      0.386035
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                      0.383312
#
#                                                     lobjois-log-num-nodes-over-vars  \
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                         0.765035
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                         0.719841
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                         0.700129
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                         0.933892
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                         0.786043
#
#                                                     lobjois-featuretime
# instance
# barthel/n210/gen_n210_m903_k3SAT_seed3555821415...                 1.14
# barthel/n210/gen_n210_m903_k3SAT_seed862748622.cnf                 1.10
# barthel/n210/gen_n210_m903_k3SAT_seed3576518490...                 1.12
# barthel/n210/gen_n210_m903_k3SAT_seed2527888016...                 1.16
# barthel/n210/gen_n210_m903_k3SAT_seed3919912883...                 1.16
#
# [5 rows x 81 columns]

# %%
merged_data = pd.concat([df, fits], join='inner', axis=1)

# %%
v2 = merged_data[merged_data['p1']<1.0]
y = v2[['p1', 'lambda1', 'lambda2']]
X = v2.drop(['p1', 'p2', 'lambda1', 'lambda2'], axis=1)

# %%
regr_rf = RandomForestRegressor()
regr_rf.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
dump(regr_rf, 'rf_regressor.joblib')
# Out:
# ['rf_regressor.joblib']

# %%
regr_rf = load('rf_regressor.joblib')

# %%
regr_rf.predict(X)
# Out:
# array([[8.22933333e-01, 2.12648425e+05, 4.30166305e+07],
#        [7.49366667e-01, 7.12882210e+03, 3.73102134e+07],
#        [3.01033333e-01, 2.04523228e+04, 3.18499685e+05],
#        [7.07533333e-01, 3.73850689e+04, 2.84907455e+07],
#        [7.16966667e-01, 6.15304796e+03, 1.23425901e+10],
#        [8.37200000e-01, 1.72223364e+05, 2.85690247e+08],
#        [8.30166667e-01, 6.78179076e+04, 3.26524268e+07],
#        [2.05166667e-01, 1.91380932e+04, 1.01832029e+08],
#        [8.73666667e-01, 6.83956425e+03, 3.36240094e+07],
#        [8.01533333e-01, 5.24913808e+07, 5.30447506e+08],
#        [7.24066667e-01, 5.24888212e+07, 2.49108787e+09],
#        [3.45166667e-01, 9.95512458e+03, 2.52947592e+07],
#        [8.03133333e-01, 3.02602696e+04, 9.04879105e+07],
#        [7.97000000e-01, 3.80417225e+04, 2.19530467e+08],
#        [8.87600000e-01, 2.40942383e+04, 2.15131550e+07],
#        [2.29666667e-02, 8.40096236e+03, 2.82985228e+08],
#        [2.70666667e-02, 5.05180220e+02, 7.82220887e+09],
#        [9.63333333e-03, 4.13944558e+02, 6.05783264e+09],
#        [1.72366667e-01, 8.39786114e+08, 7.08195966e+09],
#        [1.39000000e-02, 9.26050676e+02, 1.08620276e+09],
#        [3.93333333e-02, 6.03289423e+02, 6.41353855e+09],
#        [4.93666667e-02, 1.50361824e+03, 4.34875074e+08],
#        [4.83000000e-02, 1.39191334e+03, 6.87819835e+09],
#        [1.29000000e-01, 8.00591705e+02, 1.86581762e+09],
#        [5.42000000e-02, 4.51738219e+06, 3.75316567e+08],
#        [2.01666667e-02, 5.30995982e+02, 1.60179606e+09],
#        [2.40333333e-02, 5.24871764e+07, 2.11984294e+09],
#        [2.75666667e-02, 9.35692973e+02, 8.21069414e+07],
#        [9.35333333e-02, 5.24874773e+07, 4.88473425e+08],
#        [3.72333333e-02, 8.23185907e+02, 2.10456987e+08],
#        [4.99000000e-02, 1.29116027e+03, 1.50567756e+09],
#        [1.46400000e-01, 6.29837241e+08, 4.53449875e+10],
#        [3.40666667e-02, 1.25496824e+03, 6.72277180e+08],
#        [2.98333333e-02, 3.08950468e+02, 3.77721118e+07],
#        [2.60666667e-02, 3.32566199e+02, 1.12920420e+08],
#        [4.62666667e-02, 4.25358855e+02, 2.46758928e+06],
#        [4.63666667e-02, 1.18366576e+03, 1.77348644e+08],
#        [1.03833333e-01, 7.22910463e+02, 3.10846520e+07],
#        [3.08333333e-02, 4.63257366e+02, 2.69442012e+07],
#        [7.02000000e-02, 4.67786105e+02, 1.32147452e+07],
#        [1.66333333e-02, 5.31905208e+02, 3.12262884e+06],
#        [4.55666667e-02, 5.70101232e+07, 1.74683501e+09],
#        [1.29766667e-01, 5.24864374e+08, 4.40127631e+09],
#        [2.71000000e-02, 5.31142483e+02, 1.08304898e+07],
#        [3.38000000e-02, 2.79377608e+02, 7.21387229e+07],
#        [4.02666667e-02, 8.78477849e+02, 2.40628622e+07],
#        [2.05333333e-02, 7.46290550e+02, 3.73748720e+07],
#        [5.27333333e-02, 1.34450211e+03, 3.44161216e+06],
#        [6.63000000e-02, 2.14801211e+03, 4.99595213e+06],
#        [4.10333333e-02, 5.12148124e+02, 1.62254990e+08],
#        [2.36000000e-02, 4.93376122e+02, 1.23867154e+07],
#        [5.36666667e-02, 5.80806833e+02, 3.76460541e+07],
#        [7.46000000e-02, 9.82513290e+02, 3.90871002e+08],
#        [4.03000000e-02, 9.45615337e+02, 4.15205112e+06],
#        [2.22666667e-02, 6.85802095e+02, 2.67765274e+08],
#        [5.29333333e-02, 4.59722932e+03, 1.00054323e+08],
#        [6.48733333e-01, 3.35913048e+09, 2.35023349e+10],
#        [2.92333333e-02, 7.15214307e+02, 5.24521048e+08],
#        [2.28333333e-02, 4.62230933e+02, 3.76531356e+07],
#        [4.41000000e-02, 9.07544838e+02, 3.57773349e+07],
#        [5.46000000e-02, 1.52109141e+03, 9.65245331e+06],
#        [3.61333333e-02, 5.24868264e+07, 1.29516967e+09],
#        [4.47000000e-02, 5.24870038e+07, 4.03714815e+08],
#        [2.43000000e-02, 3.97141927e+02, 1.54671708e+07],
#        [1.96000000e-02, 7.18245553e+02, 1.14399867e+09],
#        [1.42066667e-01, 2.21138971e+03, 1.52015481e+08],
#        [2.44666667e-02, 1.15393252e+03, 1.19370634e+08],
#        [2.81666667e-02, 1.43442236e+03, 7.51273250e+07],
#        [7.40000000e-02, 5.24868176e+07, 3.75876307e+08],
#        [7.45666667e-02, 4.51709921e+06, 3.09545409e+07],
#        [1.54666667e-02, 1.60813336e+02, 1.11235055e+08],
#        [1.18333333e-02, 4.11320515e+02, 1.54347322e+08],
#        [3.70666667e-02, 4.74333302e+02, 3.19489777e+08],
#        [5.91333333e-02, 1.35602669e+07, 4.56261795e+08],
#        [1.67733333e-01, 3.81542134e+02, 6.53104721e+09],
#        [2.34666667e-02, 7.35206187e+02, 1.01621361e+07],
#        [9.08000000e-02, 4.67202065e+02, 6.36502393e+05],
#        [4.86333333e-02, 2.19216868e+03, 1.27457564e+06],
#        [5.82333333e-02, 7.39300957e+02, 2.33202725e+06],
#        [3.91000000e-02, 4.94450761e+02, 2.06674768e+06],
#        [2.81666667e-02, 6.73522958e+02, 3.39562897e+06],
#        [3.04000000e-02, 4.52047132e+06, 9.45298399e+07],
#        [4.87666667e-02, 4.47523990e+02, 4.62618946e+06],
#        [3.83666667e-02, 5.15550605e+02, 3.27477162e+07],
#        [7.71000000e-02, 1.03403736e+04, 1.92823096e+07],
#        [3.99666667e-02, 1.13943717e+03, 8.05913363e+06],
#        [2.14266667e-01, 4.13723864e+03, 2.70883861e+07],
#        [8.39000000e-02, 3.16204251e+07, 1.46021639e+09],
#        [2.96000000e-02, 1.87801823e+04, 1.10710070e+07],
#        [2.19333333e-02, 5.56969286e+02, 7.86047192e+06],
#        [2.93666667e-02, 3.58481122e+02, 5.13715955e+08],
#        [1.66100000e-01, 8.39782751e+08, 6.69967716e+09],
#        [4.36333333e-02, 5.24875120e+07, 4.19967815e+08],
#        [3.42666667e-02, 3.49397835e+02, 2.84561371e+06],
#        [9.37666667e-02, 2.09946182e+08, 1.49639104e+09],
#        [6.61666667e-02, 5.46187332e+02, 9.13063310e+06],
#        [2.30666667e-02, 8.45948656e+02, 1.79613683e+07],
#        [1.56333333e-02, 7.16327156e+02, 2.72287438e+09],
#        [2.84333333e-02, 1.66895940e+03, 4.31394214e+08],
#        [3.94666667e-02, 9.03397487e+06, 3.89301404e+08],
#        [4.04000000e-02, 1.04973650e+08, 7.78056823e+08],
#        [4.39000000e-02, 4.51710866e+06, 1.67619786e+08],
#        [3.27333333e-02, 1.20997014e+03, 1.00212059e+07],
#        [3.35000000e-02, 3.77863519e+02, 3.67218754e+07],
#        [6.47658333e-01, 3.52399867e+03, 1.39339438e+09],
#        [6.73358333e-01, 1.54305017e+02, 8.34213895e+07],
#        [3.16000000e-02, 1.02398206e+02, 2.01101831e+06],
#        [6.52391667e-01, 9.03346906e+06, 2.85743404e+09],
#        [3.80666667e-02, 6.89029430e+01, 1.90105013e+07],
#        [1.11966667e-01, 5.04804874e+01, 1.73579907e+07],
#        [1.01066667e-01, 6.73172083e+01, 6.19174041e+07],
#        [1.25066667e-01, 4.79466897e+01, 1.89932661e+07],
#        [1.43891667e-01, 2.26629667e+07, 3.01423918e+09],
#        [4.25333333e-02, 1.01489723e+04, 8.99284531e+07],
#        [1.26400000e-01, 4.52010546e+06, 6.62121295e+07],
#        [6.43958333e-01, 9.89758588e+01, 1.34000427e+09],
#        [8.13333333e-02, 1.01526514e+04, 1.04947363e+10],
#        [8.98333333e-02, 3.14918562e+08, 1.23960398e+10],
#        [7.13666667e-02, 4.58334222e+01, 9.16203977e+09],
#        [9.39333333e-02, 7.36062644e+01, 8.25929250e+08],
#        [9.69333333e-02, 4.95414121e+01, 3.84569393e+07],
#        [4.20000000e-02, 3.27425000e+01, 9.14911717e+09],
#        [7.50666667e-02, 9.03339938e+06, 6.68368609e+07],
#        [7.87666667e-02, 1.01416243e+02, 1.15365484e+08],
#        [8.91000000e-02, 4.51677364e+06, 3.17798396e+07],
#        [7.25000000e-02, 6.04621236e+01, 2.61279469e+09],
#        [5.93333333e-02, 1.35501127e+07, 4.89325479e+09],
#        [5.61666667e-02, 1.80734706e+07, 3.49400450e+08],
#        [1.81000000e-02, 4.53358504e+06, 1.31620131e+09],
#        [3.11333333e-02, 7.53707975e+01, 9.27688809e+10],
#        [6.23333333e-02, 2.25834451e+07, 3.50760699e+08],
#        [3.03333333e-02, 1.00696280e+02, 1.75842351e+09],
#        [2.48333333e-02, 2.44504075e+02, 7.38081822e+06],
#        [4.52333333e-02, 9.03368746e+06, 2.15766483e+08],
#        [4.57000000e-02, 1.07108920e+03, 1.43722591e+07],
#        [2.67000000e-02, 1.60640251e+02, 2.29765541e+07],
#        [6.87000000e-01, 3.11650648e+08, 2.17218400e+09],
#        [1.69000000e-02, 4.51888289e+02, 5.09693397e+06],
#        [4.55000000e-02, 2.15315115e+02, 5.11784055e+07],
#        [6.25333333e-02, 1.43485210e+02, 6.04687272e+07],
#        [4.18333333e-02, 1.76494847e+02, 1.31836391e+09],
#        [6.45333333e-02, 3.21647253e+05, 6.00912293e+08],
#        [8.64000000e-02, 1.80673117e+07, 1.55634369e+08],
#        [7.45250000e-02, 7.03168155e+01, 2.06161061e+09],
#        [1.80000000e-02, 9.83075701e+01, 1.31405521e+07],
#        [1.15900000e-01, 4.06503876e+07, 8.46298793e+08],
#        [2.39666667e-02, 2.36115499e+04, 2.20398038e+08],
#        [8.60333333e-02, 1.35501629e+07, 1.27087056e+08],
#        [6.95666667e-02, 8.59527220e+01, 7.69496989e+07],
#        [1.27333333e-02, 1.94823049e+02, 2.26675354e+08],
#        [6.20125000e-01, 9.03691487e+06, 5.64038551e+09],
#        [5.09000000e-02, 9.04358299e+06, 1.82078679e+09],
#        [3.85666667e-02, 4.71177406e+06, 6.94368641e+08],
#        [4.67666667e-02, 9.27235206e+06, 2.37164101e+10],
#        [2.84666667e-02, 4.52375701e+06, 1.49279345e+09],
#        [3.58666667e-02, 9.03368557e+06, 1.71576661e+08],
#        [2.78000000e-02, 4.04026933e+03, 5.30222731e+07],
#        [1.86666667e-02, 1.04062752e+07, 1.62505095e+10]])
